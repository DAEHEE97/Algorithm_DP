# %% [markdown]
# # [10844_DP-쉬운 계단 수](https://www.acmicpc.net/problem/10844)
#
# - 1 <= N <= 100 (N은 1보다 크거나 같고, 100보다 작거나 같은 자연수)
#
# - dp[i][j] : i 길이의 계단수 가 j 로 끝나는 개수

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
