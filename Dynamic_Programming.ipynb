# %% [markdown]
# # Dynamic_Programming

# %% [markdown]
# ---

# %% [markdown]
# - 이미 계산된 결과(작은 문제)는 별도의 메모리 영역 dp 테이블의 저장하여, 다시 계산 하지 않도록 처리
#     - 메모리를 적절히 사용하여, 수행 시간 효율성을 비약적으로 향상
#
# - 동적 할당(Dynamic Allocation)은 프로그램이 실행되는 도중에, 실행에 필요한 메모리를 할당하는 기법
#
#
# 1. 시각적으로 손으로 시뮬레이션 접근 > 규칙성(반복) - 점화식 인접한 항들 사이의 관계식
#
# 2. dp[] 테이블 정의, dp[i]
#
# 3. 초기값 설정, 반복처리
#
# - n에 따른 시간초과 처리

# %% [markdown]
# ---

# %% [markdown]
# ## DP 수행 조건
#
#
# 1. Optimal Substructure (최적 부분 구조)
#     - 큰 문제를 작은 문제로 나눌수 있으며, 작은 문제의 답을 모아서 큰 문제 해결
#
# 2. Overlapping Subproblem (중복되는 부분 문제)
#     - 동일한 작은 문제를 반복적으로 처리해야 하는 경우,

# %% [markdown]
# ---

# %% [markdown]
# ## Memoization
#
# 메모이제이션은, 한번 계산한 결과를 메모리 공간에 일시적으로 저장하는 기법
#
# - 같은 문제를 다시 호출하면, 메모했던 결과를 그대로 가져옵니다.
#
# - 값을 기록해 놓는다는 점에서 Caching(캐싱) 이라고도 합니다.
#
#
# - top-down (하향식) - Memoization
# - bottom-up (상향식) - DP

# %% [markdown]
# ---

# %% [markdown]
# ## fibo recur
#
# - 재귀로 처리시, 지수 시간 복잡도
#     -  f(2)를 계속해서 처리해야 함. Overlapping Subproblem

# %%
# 피보나치 함수(Fibonacci Function)을 재귀함수로 구현

def fibo(x):
    
    if x == 1 or x == 2:
        return 1
    
    return fibo(x - 1) + fibo(x - 2)

print(fibo(6))
# Out:
# 8

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ## fibo top-down (하향식) - Memoization
#
# - 시간 복잡도 O(N)

# %% [markdown]
# ---

# %%
# 피보나치 함수(Fibonacci Function)를 재귀함수로 구현 (탑다운 다이나믹 프로그래밍)

def fibo(x):
    
    print(f'f({x})')
    # 1-2) 재귀 종료 조건 처리 
    if x == 1 or x == 2:
        return 1
    
    # 1-3) Memoization, 이미 계산한 적 있는 문제라면 그대로 반환
    if dp[x] != 0:
        return dp[x]
    
    # 1-1) 점화식 처리
    dp[x] = fibo(x - 1) + fibo(x - 2)
    
    return dp[x]



# dp 테이블 생성, 메모이제이션(Memoization)하기 위한 리스트 초기화

dp = [0] * 100


print(fibo(6))
# Out:
# f(6)
# f(5)
# f(4)
# f(3)
# f(2)
# f(1)
# f(2)
# f(3)
# f(4)
# 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## fibo bottom-up (상향식) - DP

# %% [markdown]
# ---

# %%
# 앞서 계산된 결과를 저장하기 위한 DP 테이블 초기화

# 1-1) dp 테이블 정의

dp= [0] * 100

# 1-2) 초기 값 설정 
dp[1] = 1
dp[2] = 1

n = 99

# 1-1) 점화식 처리, 피보나치 함수(Fibonacci Function) 반복문으로 구현(보텀업 다이나믹 프로그래밍)

for i in range(3, n+1):
    
    dp[i] = dp[i - 1] + dp[i - 2]

print(dp[n])

# %% [markdown]
# ---

# %% [markdown]
# ## DP vs 분할 정복

# %% [markdown]
# ---

# %% [markdown]
# ## 1로 만들기

# %% [markdown]
# ---

# %% [markdown]
# ## 개미 전사

# %% [markdown]
# ---

# %% [markdown]
# ## 바닥 공사

# %% [markdown]
# ---

# %% [markdown]
# ## 효율적인 화폐 구성
